# %%
import sys
sys.version
# Out:
# '3.10.4 (main, Jun  2 2023, 21:06:04) [GCC 9.4.0]'

# %%
import numpy as np
import matplotlib as mp

# %%
np.__version__
# Out:
# '1.24.2'

# %%
mp.__version__
# Out:
# '3.7.0'

# %%
import matplotlib.pyplot as plt

# %%
x = np.array([0, 6])
y = np.array([0, 200])
plt.plot(x, y)
plt.show()

# %%
plt.plot(x)

# %%
plt.plot(y)

# %% [markdown]
# ## Plotting Without Line

# %%
x = np.array([1, 8])
y = np.array([3, 10])

# %%
plt.plot(x, y, 'o')

# %%
x = np.array([1, 2, 6, 8])
y = np.array([3, 8, 1, 10])

# %%
plt.plot(x, y)

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p)

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p)

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p, marker = 'o')

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p, marker = '*')

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p, '>-g')

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p, 'o', ms=30)

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p, ':')

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p, linestyle = 'dotted')

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p, ls = '--')

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p, '-.')

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p, 'o-r')

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p, 'o-r', lw=10)

# %%
y1 = np.array([3, 8, 1, 10, 5, 7])
y2 = np.array([6, 2, 1, 20, 4, 9])
plt.plot(y1)
plt.plot(y2)

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p, 'o-r')

# %%
p = np.array([3, 8, 1, 10, 5, 7])
plt.plot(p, 'o-r')

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [173.47204659 177.44685257 184.63032113 172.26938359 167.22440138
#  161.62378094 166.92591331 172.41161328 175.71809243 158.41381298
#  181.97350099 183.68623007 183.03230148 157.53649838 179.43251616
#  168.17094135 174.34982083 173.22613    173.13948596 190.91858545
#  175.30998449 169.69901281 161.5340542  175.09432781 173.66480783
#  183.09262843 165.17265297 149.95326792 179.51030007 173.02028255
#  162.02657199 159.70368043 172.26985809 173.91750969 172.71350988
#  193.72234319 173.76540773 158.77113625 184.86769117 161.99152092
#  165.57771441 176.0436083  150.52639016 163.43995296 157.56534312
#  179.52249972 180.78715965 169.33082883 157.2392818  163.3201118
#  159.81008983 182.64097271 186.51212471 166.96808062 175.24302269
#  167.48206971 179.50368701 162.33649004 157.16113405 179.34319897
#  148.83701414 169.78706946 164.43097855 166.83282281 142.21345321
#  152.89872734 196.25767087 161.31351584 173.3357835  169.12245614
# ...

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()
