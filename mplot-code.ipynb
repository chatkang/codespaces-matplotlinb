# %%
import sys
sys.version
# Out:
# '3.10.4 (main, Jun  2 2023, 21:06:04) [GCC 9.4.0]'

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.__version__
# Out:
# '1.24.2'

# %%
x = np.array([0, 6])
y = np.array([0, 200])
plt.plot(x, y)
plt.show()

# %%
plt.plot(x)

# %%
plt.plot(y)
